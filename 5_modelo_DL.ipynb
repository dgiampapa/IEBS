# %% [markdown]
# <a href="https://colab.research.google.com/github/dgiampapa/IEBS/blob/main/5_modelo_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning

# %%
# !pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 7.4 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.4

# %%
import pandas as pd
import string
import numpy as np
from nltk.tokenize import word_tokenize
import nltk
from datetime import datetime
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
import unidecode

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## instalacion NLTK

# %%
#!pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)

# %% [markdown]
# ## instalacion datetime

# %%
#!pip install datetime

# %%
pd.set_option('max_colwidth', 800) 
data = pd.read_csv("/content/drive/MyDrive/IEBS/Global Proyect/datos/scoreprueba/score-total.csv", index_col=0)
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0.1.1               source  \
# 0             0               0  Twitter for Android
# 1             1               1   Twitter for iPhone
# 2             2               2   Twitter for iPhone
# 3             3               3   Twitter for iPhone
# 4             4               4            Metricool
#
#                                                                                                                                                                                                                               text  \
# 0      tengan cuidado con estos sms  casualmente a mi me va a caducar mi tarjeta y en un descuido podria haber caido en la estafa  nunca pinchen enlaces de bancos ni comercios tipo carrefour  son falsos  https   t co qgexvekgu
# 1  la señora es una mas de los desgraciados  globalistas y comunistas de la agenda   si su padre levantara la cabeza la empalaba en una estaca de avellano hasta que la saliera por la boca  adivinad por donde entraria la estaca
# 2                                                                                                                                                                                             culpa tuya por trabajar con ellos
# 3                                                                                            cuidado  estafadores haciendose pasar por enviando sms para robarte los datos  no sabian que no tengo santander  https   t co iegbzed
# 4                                                                           🤝 santander es ofrece cursos para formar a sus empleados en sostenibilidad🟢  rrhh  cursos  sostenibilidad  santander  rsc  asg https   t co jxsbqowmzg
#
#    possibly_sensitive                   id  \
# 0               False  1561410269074624513
# 1               False  1561391290482401282
# 2               False  1561390305961713665
# 3               False  1561383588079321088
# 4               False  1561375377448116229
#
#                                                               public_metrics  \
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 3  {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}
#
#                   created_at      conversation_id lang            author_id  \
# 0  2022-08-21 17:49:52+00:00  1561410269074624513   es  1129278036086595584
# 1  2022-08-21 16:34:27+00:00  1561091985296990211   es            471258395
# 2  2022-08-21 16:30:32+00:00  1560971603697082369   es   810953027049975809
# 3  2022-08-21 16:03:51+00:00  1561383588079321088   es  1296205551962128385
# 4  2022-08-21 15:31:13+00:00  1561375377448116229   es             98842002
#
#    geo       neg       neu       pos score
# 0  NaN  0.933798  0.064603  0.001600   neg
# 1  NaN  0.997818  0.001756  0.000427   neg
# 2  NaN  0.957792  0.039088  0.003120   neg
# 3  NaN  0.991035  0.008265  0.000700   neg
# 4  NaN  0.013867  0.949543  0.036591   neu

# %%
data.shape
# Out:
# (3390, 16)

# %%
df_cleaning = data

# %%
df_cleaning.dtypes
# Out:
# Unnamed: 0.1            int64
# Unnamed: 0.1.1          int64
# source                 object
# text                   object
# possibly_sensitive       bool
# id                      int64
# public_metrics         object
# created_at             object
# conversation_id         int64
# lang                   object
# author_id               int64
# geo                    object
# neg                   float64
# neu                   float64
# pos                   float64
# score                  object
# dtype: object

# %% [markdown]
# ## Remover duplicados  mover 1

# %%
df_cleaning.drop_duplicates(inplace=True)

# %%
df_cleaning.shape
# Out:
# (3390, 16)

# %% [markdown]
# ## Revisar y Eliminar Null

# %%
df_cleaning.isna().sum()
# Out:
# Unnamed: 0.1             0
# Unnamed: 0.1.1           0
# source                   0
# text                     0
# possibly_sensitive       0
# id                       0
# public_metrics           0
# created_at               0
# conversation_id          0
# lang                     0
# author_id                0
# geo                   3303
# neg                      0
# neu                      0
# pos                      0
# score                    0
# dtype: int64

# %%
# La columna geo esta en null casi toda
#df_cleaning.dropna(axis=0, inplace=True)

# %%
df_cleaning.isna().sum()
# Out:
# Unnamed: 0.1             0
# Unnamed: 0.1.1           0
# source                   0
# text                     0
# possibly_sensitive       0
# id                       0
# public_metrics           0
# created_at               0
# conversation_id          0
# lang                     0
# author_id                0
# geo                   3303
# neg                      0
# neu                      0
# pos                      0
# score                    0
# dtype: int64

# %% [markdown]
# ## Eliminar menciones

# %%
def remove_mencion(text):
    text = " ".join(filter(lambda x:x[0]!='@', text.split()))
    return text

# %%
df_cleaning['text'] = df_cleaning['text'].apply(remove_mencion)
df_cleaning.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0.1.1               source  \
# 0             0               0  Twitter for Android
# 1             1               1   Twitter for iPhone
# 2             2               2   Twitter for iPhone
# 3             3               3   Twitter for iPhone
# 4             4               4            Metricool
#
#                                                                                                                                                                                                                           text  \
# 0        tengan cuidado con estos sms casualmente a mi me va a caducar mi tarjeta y en un descuido podria haber caido en la estafa nunca pinchen enlaces de bancos ni comercios tipo carrefour son falsos https t co qgexvekgu
# 1  la señora es una mas de los desgraciados globalistas y comunistas de la agenda si su padre levantara la cabeza la empalaba en una estaca de avellano hasta que la saliera por la boca adivinad por donde entraria la estaca
# 2                                                                                                                                                                                            culpa tuya por trabajar con ellos
# 3                                                                                             cuidado estafadores haciendose pasar por enviando sms para robarte los datos no sabian que no tengo santander https t co iegbzed
# 4                                                                               🤝 santander es ofrece cursos para formar a sus empleados en sostenibilidad🟢 rrhh cursos sostenibilidad santander rsc asg https t co jxsbqowmzg
#
#    possibly_sensitive                   id  \
# 0               False  1561410269074624513
# 1               False  1561391290482401282
# 2               False  1561390305961713665
# 3               False  1561383588079321088
# 4               False  1561375377448116229
#
#                                                               public_metrics  \
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 3  {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}
#
#                   created_at      conversation_id lang            author_id  \
# 0  2022-08-21 17:49:52+00:00  1561410269074624513   es  1129278036086595584
# 1  2022-08-21 16:34:27+00:00  1561091985296990211   es            471258395
# 2  2022-08-21 16:30:32+00:00  1560971603697082369   es   810953027049975809
# 3  2022-08-21 16:03:51+00:00  1561383588079321088   es  1296205551962128385
# 4  2022-08-21 15:31:13+00:00  1561375377448116229   es             98842002
#
#    geo       neg       neu       pos score
# 0  NaN  0.933798  0.064603  0.001600   neg
# 1  NaN  0.997818  0.001756  0.000427   neg
# 2  NaN  0.957792  0.039088  0.003120   neg
# 3  NaN  0.991035  0.008265  0.000700   neg
# 4  NaN  0.013867  0.949543  0.036591   neu

# %% [markdown]
# ## Formateo de campo fecha

# %%
df_cleaning['created_at'] = pd.to_datetime(df_cleaning['created_at']) #lo hacemos un objeto tiempo
df_cleaning['created_at'] = df_cleaning['created_at'].dt.strftime("%Y-%m-%d") #tomo los elementos que quiero de ese objeto
df_cleaning['created_at'] = pd.to_datetime(df_cleaning['created_at']) #vuelvo a hacerlo un objeto datetime

df_cleaning.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0.1.1               source  \
# 0             0               0  Twitter for Android
# 1             1               1   Twitter for iPhone
# 2             2               2   Twitter for iPhone
# 3             3               3   Twitter for iPhone
# 4             4               4            Metricool
#
#                                                                                                                                                                                                                           text  \
# 0        tengan cuidado con estos sms casualmente a mi me va a caducar mi tarjeta y en un descuido podria haber caido en la estafa nunca pinchen enlaces de bancos ni comercios tipo carrefour son falsos https t co qgexvekgu
# 1  la señora es una mas de los desgraciados globalistas y comunistas de la agenda si su padre levantara la cabeza la empalaba en una estaca de avellano hasta que la saliera por la boca adivinad por donde entraria la estaca
# 2                                                                                                                                                                                            culpa tuya por trabajar con ellos
# 3                                                                                             cuidado estafadores haciendose pasar por enviando sms para robarte los datos no sabian que no tengo santander https t co iegbzed
# 4                                                                               🤝 santander es ofrece cursos para formar a sus empleados en sostenibilidad🟢 rrhh cursos sostenibilidad santander rsc asg https t co jxsbqowmzg
#
#    possibly_sensitive                   id  \
# 0               False  1561410269074624513
# 1               False  1561391290482401282
# 2               False  1561390305961713665
# 3               False  1561383588079321088
# 4               False  1561375377448116229
#
#                                                               public_metrics  \
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 3  {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}
#
#   created_at      conversation_id lang            author_id  geo       neg  \
# 0 2022-08-21  1561410269074624513   es  1129278036086595584  NaN  0.933798
# 1 2022-08-21  1561091985296990211   es            471258395  NaN  0.997818
# 2 2022-08-21  1560971603697082369   es   810953027049975809  NaN  0.957792
# 3 2022-08-21  1561383588079321088   es  1296205551962128385  NaN  0.991035
# 4 2022-08-21  1561375377448116229   es             98842002  NaN  0.013867
#
#         neu       pos score
# 0  0.064603  0.001600   neg
# 1  0.001756  0.000427   neg
# 2  0.039088  0.003120   neg
# 3  0.008265  0.000700   neg
# 4  0.949543  0.036591   neu

# %% [markdown]
# ## Remplaza palabra 't pago' por 'tpago'

# %%
df_cleaning['text'] = df_cleaning['text'].str.replace('t pago', 'tpago')
df_cleaning.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0.1.1               source  \
# 0             0               0  Twitter for Android
# 1             1               1   Twitter for iPhone
# 2             2               2   Twitter for iPhone
# 3             3               3   Twitter for iPhone
# 4             4               4            Metricool
#
#                                                                                                                                                                                                                           text  \
# 0        tengan cuidado con estos sms casualmente a mi me va a caducar mi tarjeta y en un descuido podria haber caido en la estafa nunca pinchen enlaces de bancos ni comercios tipo carrefour son falsos https t co qgexvekgu
# 1  la señora es una mas de los desgraciados globalistas y comunistas de la agenda si su padre levantara la cabeza la empalaba en una estaca de avellano hasta que la saliera por la boca adivinad por donde entraria la estaca
# 2                                                                                                                                                                                            culpa tuya por trabajar con ellos
# 3                                                                                             cuidado estafadores haciendose pasar por enviando sms para robarte los datos no sabian que no tengo santander https t co iegbzed
# 4                                                                               🤝 santander es ofrece cursos para formar a sus empleados en sostenibilidad🟢 rrhh cursos sostenibilidad santander rsc asg https t co jxsbqowmzg
#
#    possibly_sensitive                   id  \
# 0               False  1561410269074624513
# 1               False  1561391290482401282
# 2               False  1561390305961713665
# 3               False  1561383588079321088
# 4               False  1561375377448116229
#
#                                                               public_metrics  \
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 3  {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}
#
#   created_at      conversation_id lang            author_id  geo       neg  \
# 0 2022-08-21  1561410269074624513   es  1129278036086595584  NaN  0.933798
# 1 2022-08-21  1561091985296990211   es            471258395  NaN  0.997818
# 2 2022-08-21  1560971603697082369   es   810953027049975809  NaN  0.957792
# 3 2022-08-21  1561383588079321088   es  1296205551962128385  NaN  0.991035
# 4 2022-08-21  1561375377448116229   es             98842002  NaN  0.013867
#
#         neu       pos score
# 0  0.064603  0.001600   neg
# 1  0.001756  0.000427   neg
# 2  0.039088  0.003120   neg
# 3  0.008265  0.000700   neg
# 4  0.949543  0.036591   neu

# %% [markdown]
# ## Elimina los caracteres iniciales (espacios al principio) y finales (espacios al final)

# %%
df_cleaning['text'] = df_cleaning['text'].str.strip()
df_cleaning.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0.1.1               source  \
# 0             0               0  Twitter for Android
# 1             1               1   Twitter for iPhone
# 2             2               2   Twitter for iPhone
# 3             3               3   Twitter for iPhone
# 4             4               4            Metricool
#
#                                                                                                                                                                                                                           text  \
# 0        tengan cuidado con estos sms casualmente a mi me va a caducar mi tarjeta y en un descuido podria haber caido en la estafa nunca pinchen enlaces de bancos ni comercios tipo carrefour son falsos https t co qgexvekgu
# 1  la señora es una mas de los desgraciados globalistas y comunistas de la agenda si su padre levantara la cabeza la empalaba en una estaca de avellano hasta que la saliera por la boca adivinad por donde entraria la estaca
# 2                                                                                                                                                                                            culpa tuya por trabajar con ellos
# 3                                                                                             cuidado estafadores haciendose pasar por enviando sms para robarte los datos no sabian que no tengo santander https t co iegbzed
# 4                                                                               🤝 santander es ofrece cursos para formar a sus empleados en sostenibilidad🟢 rrhh cursos sostenibilidad santander rsc asg https t co jxsbqowmzg
#
#    possibly_sensitive                   id  \
# 0               False  1561410269074624513
# 1               False  1561391290482401282
# 2               False  1561390305961713665
# 3               False  1561383588079321088
# 4               False  1561375377448116229
#
#                                                               public_metrics  \
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 3  {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}
#
#   created_at      conversation_id lang            author_id  geo       neg  \
# 0 2022-08-21  1561410269074624513   es  1129278036086595584  NaN  0.933798
# 1 2022-08-21  1561091985296990211   es            471258395  NaN  0.997818
# 2 2022-08-21  1560971603697082369   es   810953027049975809  NaN  0.957792
# 3 2022-08-21  1561383588079321088   es  1296205551962128385  NaN  0.991035
# 4 2022-08-21  1561375377448116229   es             98842002  NaN  0.013867
#
#         neu       pos score
# 0  0.064603  0.001600   neg
# 1  0.001756  0.000427   neg
# 2  0.039088  0.003120   neg
# 3  0.008265  0.000700   neg
# 4  0.949543  0.036591   neu

# %% [markdown]
# ## Se Eliminan los Caracteres Especiales
#
# 👇 Remove punctuation and lower case the text.

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
mi_puntuacion = '!¡"#$%&\'()*+,-./:;<=>¿?@[\\]^_`{|}~'

# %%
def remove_puntuation(text):
    for punctuation in mi_puntuacion:
        text = text.replace(punctuation, " ")
    return text

# %%
df_cleaning['text'] = df_cleaning['text'].apply(remove_puntuation)
df_cleaning.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0.1.1               source  \
# 0             0               0  Twitter for Android
# 1             1               1   Twitter for iPhone
# 2             2               2   Twitter for iPhone
# 3             3               3   Twitter for iPhone
# 4             4               4            Metricool
#
#                                                                                                                                                                                                                           text  \
# 0        tengan cuidado con estos sms casualmente a mi me va a caducar mi tarjeta y en un descuido podria haber caido en la estafa nunca pinchen enlaces de bancos ni comercios tipo carrefour son falsos https t co qgexvekgu
# 1  la señora es una mas de los desgraciados globalistas y comunistas de la agenda si su padre levantara la cabeza la empalaba en una estaca de avellano hasta que la saliera por la boca adivinad por donde entraria la estaca
# 2                                                                                                                                                                                            culpa tuya por trabajar con ellos
# 3                                                                                             cuidado estafadores haciendose pasar por enviando sms para robarte los datos no sabian que no tengo santander https t co iegbzed
# 4                                                                               🤝 santander es ofrece cursos para formar a sus empleados en sostenibilidad🟢 rrhh cursos sostenibilidad santander rsc asg https t co jxsbqowmzg
#
#    possibly_sensitive                   id  \
# 0               False  1561410269074624513
# 1               False  1561391290482401282
# 2               False  1561390305961713665
# 3               False  1561383588079321088
# 4               False  1561375377448116229
#
#                                                               public_metrics  \
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 3  {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}
#
#   created_at      conversation_id lang            author_id  geo       neg  \
# 0 2022-08-21  1561410269074624513   es  1129278036086595584  NaN  0.933798
# 1 2022-08-21  1561091985296990211   es            471258395  NaN  0.997818
# 2 2022-08-21  1560971603697082369   es   810953027049975809  NaN  0.957792
# 3 2022-08-21  1561383588079321088   es  1296205551962128385  NaN  0.991035
# 4 2022-08-21  1561375377448116229   es             98842002  NaN  0.013867
#
#         neu       pos score
# 0  0.064603  0.001600   neg
# 1  0.001756  0.000427   neg
# 2  0.039088  0.003120   neg
# 3  0.008265  0.000700   neg
# 4  0.949543  0.036591   neu

# %% [markdown]
# ## Covierte en minusculas todo

# %%
def remove_lower(text1):
    text1 = text1.lower()
    return text1

# %%
df_cleaning['text'] = df_cleaning['text'].apply(remove_lower)
df_cleaning.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0.1.1               source  \
# 0             0               0  Twitter for Android
# 1             1               1   Twitter for iPhone
# 2             2               2   Twitter for iPhone
# 3             3               3   Twitter for iPhone
# 4             4               4            Metricool
#
#                                                                                                                                                                                                                           text  \
# 0        tengan cuidado con estos sms casualmente a mi me va a caducar mi tarjeta y en un descuido podria haber caido en la estafa nunca pinchen enlaces de bancos ni comercios tipo carrefour son falsos https t co qgexvekgu
# 1  la señora es una mas de los desgraciados globalistas y comunistas de la agenda si su padre levantara la cabeza la empalaba en una estaca de avellano hasta que la saliera por la boca adivinad por donde entraria la estaca
# 2                                                                                                                                                                                            culpa tuya por trabajar con ellos
# 3                                                                                             cuidado estafadores haciendose pasar por enviando sms para robarte los datos no sabian que no tengo santander https t co iegbzed
# 4                                                                               🤝 santander es ofrece cursos para formar a sus empleados en sostenibilidad🟢 rrhh cursos sostenibilidad santander rsc asg https t co jxsbqowmzg
#
#    possibly_sensitive                   id  \
# 0               False  1561410269074624513
# 1               False  1561391290482401282
# 2               False  1561390305961713665
# 3               False  1561383588079321088
# 4               False  1561375377448116229
#
#                                                               public_metrics  \
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 3  {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}
#
#   created_at      conversation_id lang            author_id  geo       neg  \
# 0 2022-08-21  1561410269074624513   es  1129278036086595584  NaN  0.933798
# 1 2022-08-21  1561091985296990211   es            471258395  NaN  0.997818
# 2 2022-08-21  1560971603697082369   es   810953027049975809  NaN  0.957792
# 3 2022-08-21  1561383588079321088   es  1296205551962128385  NaN  0.991035
# 4 2022-08-21  1561375377448116229   es             98842002  NaN  0.013867
#
#         neu       pos score
# 0  0.064603  0.001600   neg
# 1  0.001756  0.000427   neg
# 2  0.039088  0.003120   neg
# 3  0.008265  0.000700   neg
# 4  0.949543  0.036591   neu

# %% [markdown]
# ## Elimina Acentos

# %%
from unicodedata import normalize
def cambia_acentuadas(text):
    trans_tab = dict.fromkeys(map(ord, u'\u0301\u0308'), None)
    text = normalize('NFKC', normalize('NFKD', text).translate(trans_tab))
    return text

# %%
df_cleaning['text'] = df_cleaning['text'].apply(cambia_acentuadas)
df_cleaning.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0.1.1               source  \
# 0             0               0  Twitter for Android
# 1             1               1   Twitter for iPhone
# 2             2               2   Twitter for iPhone
# 3             3               3   Twitter for iPhone
# 4             4               4            Metricool
#
#                                                                                                                                                                                                                           text  \
# 0        tengan cuidado con estos sms casualmente a mi me va a caducar mi tarjeta y en un descuido podria haber caido en la estafa nunca pinchen enlaces de bancos ni comercios tipo carrefour son falsos https t co qgexvekgu
# 1  la señora es una mas de los desgraciados globalistas y comunistas de la agenda si su padre levantara la cabeza la empalaba en una estaca de avellano hasta que la saliera por la boca adivinad por donde entraria la estaca
# 2                                                                                                                                                                                            culpa tuya por trabajar con ellos
# 3                                                                                             cuidado estafadores haciendose pasar por enviando sms para robarte los datos no sabian que no tengo santander https t co iegbzed
# 4                                                                               🤝 santander es ofrece cursos para formar a sus empleados en sostenibilidad🟢 rrhh cursos sostenibilidad santander rsc asg https t co jxsbqowmzg
#
#    possibly_sensitive                   id  \
# 0               False  1561410269074624513
# 1               False  1561391290482401282
# 2               False  1561390305961713665
# 3               False  1561383588079321088
# 4               False  1561375377448116229
#
#                                                               public_metrics  \
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 3  {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}
#
#   created_at      conversation_id lang            author_id  geo       neg  \
# 0 2022-08-21  1561410269074624513   es  1129278036086595584  NaN  0.933798
# 1 2022-08-21  1561091985296990211   es            471258395  NaN  0.997818
# 2 2022-08-21  1560971603697082369   es   810953027049975809  NaN  0.957792
# 3 2022-08-21  1561383588079321088   es  1296205551962128385  NaN  0.991035
# 4 2022-08-21  1561375377448116229   es             98842002  NaN  0.013867
#
#         neu       pos score
# 0  0.064603  0.001600   neg
# 1  0.001756  0.000427   neg
# 2  0.039088  0.003120   neg
# 3  0.008265  0.000700   neg
# 4  0.949543  0.036591   neu

# %% [markdown]
# ## Remueve Numeros

# %%
def remove_numbers(text1):
    text1 = ''.join(word for word in text1 if not word.isdigit())
    return text1

# %%
df_cleaning['text'] = df_cleaning['text'].apply(remove_numbers)
df_cleaning.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0.1.1               source  \
# 0             0               0  Twitter for Android
# 1             1               1   Twitter for iPhone
# 2             2               2   Twitter for iPhone
# 3             3               3   Twitter for iPhone
# 4             4               4            Metricool
#
#                                                                                                                                                                                                                           text  \
# 0        tengan cuidado con estos sms casualmente a mi me va a caducar mi tarjeta y en un descuido podria haber caido en la estafa nunca pinchen enlaces de bancos ni comercios tipo carrefour son falsos https t co qgexvekgu
# 1  la señora es una mas de los desgraciados globalistas y comunistas de la agenda si su padre levantara la cabeza la empalaba en una estaca de avellano hasta que la saliera por la boca adivinad por donde entraria la estaca
# 2                                                                                                                                                                                            culpa tuya por trabajar con ellos
# 3                                                                                             cuidado estafadores haciendose pasar por enviando sms para robarte los datos no sabian que no tengo santander https t co iegbzed
# 4                                                                               🤝 santander es ofrece cursos para formar a sus empleados en sostenibilidad🟢 rrhh cursos sostenibilidad santander rsc asg https t co jxsbqowmzg
#
#    possibly_sensitive                   id  \
# 0               False  1561410269074624513
# 1               False  1561391290482401282
# 2               False  1561390305961713665
# 3               False  1561383588079321088
# 4               False  1561375377448116229
#
#                                                               public_metrics  \
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 3  {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}
#
#   created_at      conversation_id lang            author_id  geo       neg  \
# 0 2022-08-21  1561410269074624513   es  1129278036086595584  NaN  0.933798
# 1 2022-08-21  1561091985296990211   es            471258395  NaN  0.997818
# 2 2022-08-21  1560971603697082369   es   810953027049975809  NaN  0.957792
# 3 2022-08-21  1561383588079321088   es  1296205551962128385  NaN  0.991035
# 4 2022-08-21  1561375377448116229   es             98842002  NaN  0.013867
#
#         neu       pos score
# 0  0.064603  0.001600   neg
# 1  0.001756  0.000427   neg
# 2  0.039088  0.003120   neg
# 3  0.008265  0.000700   neg
# 4  0.949543  0.036591   neu

# %% [markdown]
# ## Separar palabras

# %%
def remove_StopWords(text):
    spanish_stopwords = set(stopwords.words('spanish'))
    #stop_words = set(stopwords.words('spanish'))
    word_tokens = word_tokenize(text) 
    text = [w for w in word_tokens if not w in spanish_stopwords]
    return text

# %%
df_cleaning['text'] = df_cleaning['text'].apply(remove_StopWords)
df_cleaning.head()

# %% [markdown]
# ## Lemmatizer

# %%
from nltk.stem import WordNetLemmatizer
def remove_Lemmatize(text):
    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(word) for word in text]
    str_lemmatizer = " ".join(lemmatized)
    return str_lemmatizer

# %%
df_cleaning['text'] = df_cleaning['text'].apply(remove_Lemmatize)
df_cleaning.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0.1.1               source  \
# 0             0               0  Twitter for Android
# 1             1               1   Twitter for iPhone
# 2             2               2   Twitter for iPhone
# 3             3               3   Twitter for iPhone
# 4             4               4            Metricool
#
#                                                                                                                                                             text  \
# 0  cuidado sm casualmente va caducar tarjeta descuido podria haber caido estafa nunca pinchen enlaces bancos comercios tipo carrefour falsos http t co qgexvekgu
# 1                  señora ma desgraciados globalistas comunistas agenda si padre levantara cabeza empalaba estaca avellano saliera boca adivinad entraria estaca
# 2                                                                                                                                                 culpa trabajar
# 3                                                              cuidado estafadores haciendose pasar enviando sm robarte datos sabian santander http t co iegbzed
# 4                                   🤝 santander ofrece cursos formar empleados sostenibilidad🟢 rrhh cursos sostenibilidad santander rsc asg http t co jxsbqowmzg
#
#    possibly_sensitive                   id  \
# 0               False  1561410269074624513
# 1               False  1561391290482401282
# 2               False  1561390305961713665
# 3               False  1561383588079321088
# 4               False  1561375377448116229
#
#                                                               public_metrics  \
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 3  {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}
# 4  {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}
#
#   created_at      conversation_id lang            author_id  geo       neg  \
# 0 2022-08-21  1561410269074624513   es  1129278036086595584  NaN  0.933798
# 1 2022-08-21  1561091985296990211   es            471258395  NaN  0.997818
# 2 2022-08-21  1560971603697082369   es   810953027049975809  NaN  0.957792
# 3 2022-08-21  1561383588079321088   es  1296205551962128385  NaN  0.991035
# 4 2022-08-21  1561375377448116229   es             98842002  NaN  0.013867
#
#         neu       pos score
# 0  0.064603  0.001600   neg
# 1  0.001756  0.000427   neg
# 2  0.039088  0.003120   neg
# 3  0.008265  0.000700   neg
# 4  0.949543  0.036591   neu

# %%
df_cleaning.shape
# Out:
# (3390, 16)

# %% [markdown]
# ## Definir Train y test

# %%
X = df_cleaning['text']
y = df_cleaning['score']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train
# Out:
# 140                                                                                                        hola estan haciendo phishing via mensaje sm cuidado enlace http t co uxnznulu
# 592                                                                                                                                                                               teneis
# 30                                                                          bbva promocion usa codigo hacerte cuenta online comisiones tendras euro regalo primera compra tarjeta debito
# 137                                                                                                veces entran mensaje individual vez juntado hilo sm real banco persona mayor cae fijo
# 137                                                                                                        podian dignarse comunicarlo clientes buscarlo twitter mucha educacion parte 🤨
#                                                                                              ...
# 460                     hace años hice proyecto fin carrera alli poner granja castellana negra escuela gestionada alumnos raza peligro extincion costo informarme formarme llamaban loca
# 267                                                                                                           hace tiempo informo existen copias buen recaudo grababan mundo jordi pujol
# 659    country manager peio belausteguigoitia considera españa puede ser fundamental transicion sostenible europa situacion geografica condiciones medioambientales http t co rzftescbxt
# 26                                                                                            abras javi parar unicaja bank of ireland mismos confirmado fraude jamas contactaran medios
# 314                                           santander formara empleados sostenibilidad criterios asg http t co utzlii sustentabilidad sostenibilidad esg asg rse rsc http t co igymane
# Name: text, Length: 2373, dtype: object

# %% [markdown]
# ## Modelo Deep learning

# %%
# !pip install python-Levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.7/dist-packages (0.12.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein) (57.4.0)

# %%
from gensim.models import Word2Vec
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences


# –– Step #1
def convert_sentences(X):
    return [sentence.split(' ') for sentence in X]

X_train_words = convert_sentences(X_train)
X_test_words = convert_sentences(X_test)


# –– Step #2
word2vec = Word2Vec(sentences=X_train, min_count=10, window=10)


# –– Step #3
def embed_sentence(word2vec, sentence):
    embedded_sentence = []
    for word in sentence:
        if word in word2vec.wv:
            embedded_sentence.append(word2vec.wv[word])
        
    return np.array(embedded_sentence)

def embedding(word2vec, sentences):
    embed = []
    
    for sentence in sentences:
        embedded_sentence = embed_sentence(word2vec, sentence)
        embed.append(embedded_sentence)
        
    return embed

X_train_embed = embedding(word2vec, X_train_words)
X_test_embed = embedding(word2vec, X_test_words)


# –– Step #4
X_train_pad = pad_sequences(X_train_embed, dtype='float32', padding='post')
X_test_pad = pad_sequences(X_test_embed, dtype='float32', padding='post')
# Out:
# WARNING:gensim.models.word2vec:Each 'sentences' item should be a list of words (usually unicode strings). First item here is instead plain <class 'str'>.

# %%
y_train = y_train.map(lambda x : 2 if x == 'pos' else 1 if x == 'neu' else 0)

# %%
y_test = y_test.map(lambda x : 2 if x == 'pos' else 1 if x == 'neu' else 0)

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train, num_classes=3) #Convierte en categorical el train
y_test = to_categorical(y_test, num_classes=3) #Convierte en categorical el test

# %%
from tensorflow.keras import Sequential
from tensorflow.keras import layers

def init_model():
    model_dl = Sequential()
    model_dl.add(layers.Masking())
    model_dl.add(layers.LSTM(20, activation='tanh'))
    model_dl.add(layers.Dense(15, activation='relu'))
    model_dl.add(layers.Dense(3, activation='softmax'))

    model_dl.compile(loss='categorical_crossentropy',
                  optimizer='rmsprop',
                  metrics=['accuracy'])
    
    return model_dl

model_dl = init_model()

# %%
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(patience=20, restore_best_weights=True)

model_dl.fit(X_train_pad, y_train, 
          batch_size = 16,
          epochs=1000,
          validation_split=0.3,
          callbacks=[es]
         )
# Out:
# Epoch 1/1000
# 104/104 [==============================] - 9s 24ms/step - loss: 1.0069 - accuracy: 0.4702 - val_loss: 0.9382 - val_accuracy: 0.4803
# Epoch 2/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.9241 - accuracy: 0.5521 - val_loss: 0.8921 - val_accuracy: 0.5843
# Epoch 3/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8854 - accuracy: 0.5936 - val_loss: 0.8627 - val_accuracy: 0.5899
# Epoch 4/1000
# 104/104 [==============================] - 1s 8ms/step - loss: 0.8587 - accuracy: 0.6020 - val_loss: 0.8448 - val_accuracy: 0.5913
# Epoch 5/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8429 - accuracy: 0.6045 - val_loss: 0.8333 - val_accuracy: 0.5955
# Epoch 6/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8329 - accuracy: 0.6051 - val_loss: 0.8257 - val_accuracy: 0.5955
# Epoch 7/1000
# 104/104 [==============================] - 1s 8ms/step - loss: 0.8270 - accuracy: 0.6033 - val_loss: 0.8206 - val_accuracy: 0.5969
# Epoch 8/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8239 - accuracy: 0.6051 - val_loss: 0.8199 - val_accuracy: 0.5983
# Epoch 9/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8219 - accuracy: 0.6020 - val_loss: 0.8173 - val_accuracy: 0.5997
# Epoch 10/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8192 - accuracy: 0.6051 - val_loss: 0.8183 - val_accuracy: 0.5969
# Epoch 11/1000
# 104/104 [==============================] - 1s 8ms/step - loss: 0.8181 - accuracy: 0.6069 - val_loss: 0.8172 - val_accuracy: 0.5983
# Epoch 12/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8180 - accuracy: 0.6075 - val_loss: 0.8153 - val_accuracy: 0.5983
# Epoch 13/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8166 - accuracy: 0.6051 - val_loss: 0.8132 - val_accuracy: 0.5983
# Epoch 14/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8164 - accuracy: 0.6051 - val_loss: 0.8158 - val_accuracy: 0.6039
# Epoch 15/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8166 - accuracy: 0.6081 - val_loss: 0.8139 - val_accuracy: 0.6039
# Epoch 16/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8145 - accuracy: 0.6075 - val_loss: 0.8115 - val_accuracy: 0.6039
# Epoch 17/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8164 - accuracy: 0.6087 - val_loss: 0.8120 - val_accuracy: 0.6039
# Epoch 18/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8156 - accuracy: 0.6069 - val_loss: 0.8129 - val_accuracy: 0.6039
# Epoch 19/1000
# 104/104 [==============================] - 1s 8ms/step - loss: 0.8146 - accuracy: 0.6075 - val_loss: 0.8098 - val_accuracy: 0.6039
# Epoch 20/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8143 - accuracy: 0.6087 - val_loss: 0.8148 - val_accuracy: 0.6039
# Epoch 21/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8152 - accuracy: 0.6087 - val_loss: 0.8106 - val_accuracy: 0.6025
# Epoch 22/1000
# 104/104 [==============================] - 1s 8ms/step - loss: 0.8141 - accuracy: 0.6093 - val_loss: 0.8151 - val_accuracy: 0.6053
# Epoch 23/1000
# 104/104 [==============================] - 1s 8ms/step - loss: 0.8140 - accuracy: 0.6099 - val_loss: 0.8106 - val_accuracy: 0.6039
# Epoch 24/1000
# 104/104 [==============================] - 1s 8ms/step - loss: 0.8131 - accuracy: 0.6087 - val_loss: 0.8109 - val_accuracy: 0.6039
# Epoch 25/1000
# 104/104 [==============================] - 1s 8ms/step - loss: 0.8104 - accuracy: 0.6093 - val_loss: 0.8138 - val_accuracy: 0.6025
# Epoch 26/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8126 - accuracy: 0.6081 - val_loss: 0.8151 - val_accuracy: 0.5983
# Epoch 27/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8136 - accuracy: 0.6093 - val_loss: 0.8111 - val_accuracy: 0.6025
# Epoch 28/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8117 - accuracy: 0.6099 - val_loss: 0.8140 - val_accuracy: 0.6025
# Epoch 29/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8114 - accuracy: 0.6093 - val_loss: 0.8129 - val_accuracy: 0.6039
# Epoch 30/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8110 - accuracy: 0.6099 - val_loss: 0.8120 - val_accuracy: 0.6039
# Epoch 31/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8118 - accuracy: 0.6105 - val_loss: 0.8120 - val_accuracy: 0.6025
# Epoch 32/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8107 - accuracy: 0.6099 - val_loss: 0.8155 - val_accuracy: 0.6025
# Epoch 33/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8105 - accuracy: 0.6111 - val_loss: 0.8132 - val_accuracy: 0.6025
# Epoch 34/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8109 - accuracy: 0.6099 - val_loss: 0.8141 - val_accuracy: 0.6025
# Epoch 35/1000
# 104/104 [==============================] - 2s 15ms/step - loss: 0.8096 - accuracy: 0.6105 - val_loss: 0.8119 - val_accuracy: 0.6039
# Epoch 36/1000
# 104/104 [==============================] - 1s 13ms/step - loss: 0.8108 - accuracy: 0.6117 - val_loss: 0.8148 - val_accuracy: 0.6039
# Epoch 37/1000
# 104/104 [==============================] - 1s 13ms/step - loss: 0.8093 - accuracy: 0.6105 - val_loss: 0.8145 - val_accuracy: 0.6039
# Epoch 38/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8099 - accuracy: 0.6111 - val_loss: 0.8115 - val_accuracy: 0.6039
# Epoch 39/1000
# 104/104 [==============================] - 1s 9ms/step - loss: 0.8087 - accuracy: 0.6105 - val_loss: 0.8186 - val_accuracy: 0.6025

# %%
model_dl.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  masking (Masking)           (None, 8, 100)            0
#
#  lstm (LSTM)                 (None, 20)                9680
#
#  dense (Dense)               (None, 15)                315
#
#  dense_1 (Dense)             (None, 3)                 48
#
# =================================================================
# Total params: 10,043
# Trainable params: 10,043
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = model_dl.evaluate(X_test_pad, y_test, verbose=0)

print(f'The accuracy evaluated on the test set is of {res[1]*100:.3f}%')
# Out:
# The accuracy evaluated on the test set is of 58.800%

# %%
df_model.columns = ['pos','neg','neu']
df_model = pd.DataFrame(model_dl.predict(X_test_pad))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-3b83874cf3e5> in <module>
# ----> 1 df_model.columns = ['pos','neg','neu']
#       2 df_model = pd.DataFrame(model_dl.predict(X_test_pad))
#
# NameError: name 'df_model' is not defined
